# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('Waterloo, Ontario, Canada', network_type='drive')
fig, ax = ox.plot_graph(G, show=False, close=False, edge_color='#eb5834', bgcolor='none', edge_alpha=0.4, node_color='#eb5834')
